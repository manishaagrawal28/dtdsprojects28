# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset

from sklearn import datasets

housing=datasets.fetch_california_housing()
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
#   'Longitude'],
#  'DESCR': 'California housing dataset.\n\nThe original database is available from StatLib\n\n    http://lib.stat.cmu.edu/datasets/\n\nThe data contains 20,640 observations on 9 variables.\n\nThis dataset contains the average house value as target variable\nand the following input variables (features): average income,\nhousing average age, average rooms, average bedrooms, population,\naverage occupation, latitude, and longitude in that order.\n\nReferences\n----------\n\nPace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\nStatistics and Probability Letters, 33 (1997) 291-297.\n\n'}

# %%
#find the key value 
housing.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %%
#check the data
housing.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
#find target
housing.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
#check the featurenames
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
#describe the dataset
housing.DESCR
# Out:
# 'California housing dataset.\n\nThe original database is available from StatLib\n\n    http://lib.stat.cmu.edu/datasets/\n\nThe data contains 20,640 observations on 9 variables.\n\nThis dataset contains the average house value as target variable\nand the following input variables (features): average income,\nhousing average age, average rooms, average bedrooms, population,\naverage occupation, latitude, and longitude in that order.\n\nReferences\n----------\n\nPace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,\nStatistics and Probability Letters, 33 (1997) 291-297.\n\n'

# %%
#loading the data into dataframe
import pandas as pd
df=pd.DataFrame(housing.data,columns=housing.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6      3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7      3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8      2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9      3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
# 10     3.2031      52.0  5.477612   1.079602       910.0  2.263682     37.85
# 11     3.2705      52.0  4.772480   1.024523      1504.0  2.049046     37.85
# 12     3.0750      52.0  5.322650   1.012821      1098.0  2.346154     37.85
# 13     2.6736      52.0  4.000000   1.097701       345.0  1.982759     37.84
# 14     1.9167      52.0  4.262903   1.009677      1212.0  1.954839     37.85
# 15     2.1250      50.0  4.242424   1.071970       697.0  2.640152     37.85
# 16     2.7750      52.0  5.939577   1.048338       793.0  2.395770     37.85
# 17     2.1202      52.0  4.052805   0.966997       648.0  2.138614     37.85
# 18     1.9911      50.0  5.343675   1.085919       990.0  2.362768     37.84
# 19     2.6033      52.0  5.465455   1.083636       690.0  2.509091     37.84
# 20     1.3578      40.0  4.524096   1.108434       409.0  2.463855     37.85
# 21     1.7135      42.0  4.478142   1.002732       929.0  2.538251     37.85
# 22     1.7250      52.0  5.096234   1.131799      1015.0  2.123431     37.84
# 23     2.1806      52.0  5.193846   1.036923       853.0  2.624615     37.84
# 24     2.6000      52.0  5.270142   1.035545      1006.0  2.383886     37.84
# 25     2.4038      41.0  4.495798   1.033613       317.0  2.663866     37.85
# 26     2.4597      49.0  4.728033   1.020921       607.0  2.539749     37.85
# 27     1.8080      52.0  4.780856   1.060453      1102.0  2.775819     37.85
# 28     1.6424      50.0  4.401691   1.040169      1131.0  2.391121     37.84
# 29     1.6875      52.0  4.703226   1.032258       395.0  2.548387     37.84
# ...       ...       ...       ...        ...         ...       ...       ...
# 20610  1.3631      28.0  4.851936   1.102506      1195.0  2.722096     39.10
# 20611  1.2857      27.0  4.359413   1.078240      1163.0  2.843521     39.10
# 20612  1.4934      26.0  5.157303   1.082397       761.0  2.850187     39.08
# 20613  1.4958      31.0  4.500000   0.950521      1167.0  3.039062     39.09
# 20614  2.4695      26.0  4.801688   0.970464      1455.0  3.069620     39.08
# 20615  2.3598      23.0  5.461929   1.096447       724.0  3.675127     39.08
# 20616  2.0469      15.0  4.826667   1.176000      1157.0  3.085333     39.08
# 20617  3.3021      20.0  4.921053   0.956140       308.0  2.701754     39.06
# 20618  2.2500      25.0  5.893805   1.092920       726.0  3.212389     39.06
# 20619  2.7303      22.0  6.388514   1.148649      1023.0  3.456081     39.01
# 20620  4.5625      40.0  4.125000   0.854167       151.0  3.145833     39.05
# 20621  2.3661      37.0  7.923567   1.573248       484.0  3.082803     39.01
# 20622  2.4167      20.0  4.808917   0.936306       457.0  2.910828     39.00
# 20623  2.8235      32.0  5.101322   1.074890       598.0  2.634361     39.03
# 20624  3.0739      16.0  5.835052   1.030928       731.0  2.512027     39.04
# 20625  4.1250      37.0  7.285714   1.214286        29.0  2.071429     39.12
# 20626  2.1667      36.0  6.573099   1.076023       504.0  2.947368     39.18
# 20627  3.0000       5.0  6.067797   1.101695       169.0  2.864407     39.13
# 20628  2.5952      19.0  5.238462   1.079487      1018.0  2.610256     39.10
# 20629  2.0943      28.0  5.519802   1.020902      6912.0  3.801980     39.12
# 20630  3.5673      11.0  5.932584   1.134831      1257.0  2.824719     39.29
# 20631  3.5179      15.0  6.145833   1.141204      1200.0  2.777778     39.33
# 20632  3.1250      15.0  6.023377   1.080519      1047.0  2.719481     39.26
# 20633  2.5495      27.0  5.445026   1.078534      1082.0  2.832461     39.19
# 20634  3.7125      28.0  6.779070   1.148256      1041.0  3.026163     39.27
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# 5        -122.25
# 6        -122.25
# 7        -122.25
# 8        -122.26
# 9        -122.25
# 10       -122.26
# 11       -122.26
# 12       -122.26
# 13       -122.26
# 14       -122.26
# 15       -122.26
# 16       -122.27
# 17       -122.27
# 18       -122.26
# 19       -122.27
# 20       -122.27
# 21       -122.27
# 22       -122.27
# 23       -122.27
# 24       -122.27
# 25       -122.28
# 26       -122.28
# 27       -122.28
# 28       -122.28
# 29       -122.28
# ...          ...
# 20610    -121.56
# 20611    -121.55
# 20612    -121.56
# 20613    -121.55
# 20614    -121.54
# 20615    -121.54
# 20616    -121.53
# 20617    -121.53
# 20618    -121.55
# 20619    -121.56
# 20620    -121.48
# 20621    -121.47
# 20622    -121.44
# 20623    -121.37
# 20624    -121.41
# 20625    -121.52
# 20626    -121.43
# 20627    -121.32
# 20628    -121.48
# 20629    -121.39
# 20630    -121.32
# 20631    -121.40
# 20632    -121.45
# 20633    -121.53
# 20634    -121.56
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
#add the target column into the data
df['target']=housing.target

# %%
#check the names of columns
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'target'],
#       dtype='object')

# %%
#check the entire data
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6      3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7      3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8      2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9      3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
# 10     3.2031      52.0  5.477612   1.079602       910.0  2.263682     37.85
# 11     3.2705      52.0  4.772480   1.024523      1504.0  2.049046     37.85
# 12     3.0750      52.0  5.322650   1.012821      1098.0  2.346154     37.85
# 13     2.6736      52.0  4.000000   1.097701       345.0  1.982759     37.84
# 14     1.9167      52.0  4.262903   1.009677      1212.0  1.954839     37.85
# 15     2.1250      50.0  4.242424   1.071970       697.0  2.640152     37.85
# 16     2.7750      52.0  5.939577   1.048338       793.0  2.395770     37.85
# 17     2.1202      52.0  4.052805   0.966997       648.0  2.138614     37.85
# 18     1.9911      50.0  5.343675   1.085919       990.0  2.362768     37.84
# 19     2.6033      52.0  5.465455   1.083636       690.0  2.509091     37.84
# 20     1.3578      40.0  4.524096   1.108434       409.0  2.463855     37.85
# 21     1.7135      42.0  4.478142   1.002732       929.0  2.538251     37.85
# 22     1.7250      52.0  5.096234   1.131799      1015.0  2.123431     37.84
# 23     2.1806      52.0  5.193846   1.036923       853.0  2.624615     37.84
# 24     2.6000      52.0  5.270142   1.035545      1006.0  2.383886     37.84
# 25     2.4038      41.0  4.495798   1.033613       317.0  2.663866     37.85
# 26     2.4597      49.0  4.728033   1.020921       607.0  2.539749     37.85
# 27     1.8080      52.0  4.780856   1.060453      1102.0  2.775819     37.85
# 28     1.6424      50.0  4.401691   1.040169      1131.0  2.391121     37.84
# 29     1.6875      52.0  4.703226   1.032258       395.0  2.548387     37.84
# ...       ...       ...       ...        ...         ...       ...       ...
# 20610  1.3631      28.0  4.851936   1.102506      1195.0  2.722096     39.10
# 20611  1.2857      27.0  4.359413   1.078240      1163.0  2.843521     39.10
# 20612  1.4934      26.0  5.157303   1.082397       761.0  2.850187     39.08
# 20613  1.4958      31.0  4.500000   0.950521      1167.0  3.039062     39.09
# 20614  2.4695      26.0  4.801688   0.970464      1455.0  3.069620     39.08
# 20615  2.3598      23.0  5.461929   1.096447       724.0  3.675127     39.08
# 20616  2.0469      15.0  4.826667   1.176000      1157.0  3.085333     39.08
# 20617  3.3021      20.0  4.921053   0.956140       308.0  2.701754     39.06
# 20618  2.2500      25.0  5.893805   1.092920       726.0  3.212389     39.06
# 20619  2.7303      22.0  6.388514   1.148649      1023.0  3.456081     39.01
# 20620  4.5625      40.0  4.125000   0.854167       151.0  3.145833     39.05
# 20621  2.3661      37.0  7.923567   1.573248       484.0  3.082803     39.01
# 20622  2.4167      20.0  4.808917   0.936306       457.0  2.910828     39.00
# 20623  2.8235      32.0  5.101322   1.074890       598.0  2.634361     39.03
# 20624  3.0739      16.0  5.835052   1.030928       731.0  2.512027     39.04
# 20625  4.1250      37.0  7.285714   1.214286        29.0  2.071429     39.12
# 20626  2.1667      36.0  6.573099   1.076023       504.0  2.947368     39.18
# 20627  3.0000       5.0  6.067797   1.101695       169.0  2.864407     39.13
# 20628  2.5952      19.0  5.238462   1.079487      1018.0  2.610256     39.10
# 20629  2.0943      28.0  5.519802   1.020902      6912.0  3.801980     39.12
# 20630  3.5673      11.0  5.932584   1.134831      1257.0  2.824719     39.29
# 20631  3.5179      15.0  6.145833   1.141204      1200.0  2.777778     39.33
# 20632  3.1250      15.0  6.023377   1.080519      1047.0  2.719481     39.26
# 20633  2.5495      27.0  5.445026   1.078534      1082.0  2.832461     39.19
# 20634  3.7125      28.0  6.779070   1.148256      1041.0  3.026163     39.27
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# 0        -122.23   4.526
# 1        -122.22   3.585
# 2        -122.24   3.521
# 3        -122.25   3.413
# 4        -122.25   3.422
# 5        -122.25   2.697
# 6        -122.25   2.992
# 7        -122.25   2.414
# 8        -122.26   2.267
# 9        -122.25   2.611
# 10       -122.26   2.815
# 11       -122.26   2.418
# 12       -122.26   2.135
# 13       -122.26   1.913
# 14       -122.26   1.592
# 15       -122.26   1.400
# 16       -122.27   1.525
# 17       -122.27   1.555
# 18       -122.26   1.587
# 19       -122.27   1.629
# 20       -122.27   1.475
# 21       -122.27   1.598
# 22       -122.27   1.139
# 23       -122.27   0.997
# 24       -122.27   1.326
# 25       -122.28   1.075
# 26       -122.28   0.938
# 27       -122.28   1.055
# 28       -122.28   1.089
# 29       -122.28   1.320
# ...          ...     ...
# 20610    -121.56   0.455
# 20611    -121.55   0.470
# 20612    -121.56   0.483
# 20613    -121.55   0.534
# 20614    -121.54   0.580
# 20615    -121.54   0.575
# 20616    -121.53   0.551
# 20617    -121.53   0.708
# 20618    -121.55   0.634
# 20619    -121.56   0.991
# 20620    -121.48   1.000
# 20621    -121.47   0.775
# 20622    -121.44   0.670
# 20623    -121.37   0.655
# 20624    -121.41   0.872
# 20625    -121.52   0.720
# 20626    -121.43   0.938
# 20627    -121.32   1.625
# 20628    -121.48   0.924
# 20629    -121.39   1.083
# 20630    -121.32   1.120
# 20631    -121.40   1.072
# 20632    -121.45   1.156
# 20633    -121.53   0.983
# 20634    -121.56   1.168
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894
#
# [20640 rows x 9 columns]

# %%
#shape of the dataset
df.shape
# Out:
# (20640, 9)

# %%
#check the datatypes
df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# target        float64
# dtype: object

# %%
#checking information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
# MedInc        20640 non-null float64
# HouseAge      20640 non-null float64
# AveRooms      20640 non-null float64
# AveBedrms     20640 non-null float64
# Population    20640 non-null float64
# AveOccup      20640 non-null float64
# Latitude      20640 non-null float64
# Longitude     20640 non-null float64
# target        20640 non-null float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
#find statistical information of each column
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude        target
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
#checking whether there is a null value or not?
df.isnull().sum()  #no null data present
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
#checking null values with visualization
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.isnull())  #no missing data present

# %%
 #visualization by using pairplot of each column
sns.pairplot(df)

# %%
#visualization by using distribution plot
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df["MedInc"])  #some skewed data present

# %%
#distribution plot for specific columns
sns.distplot(df["HouseAge"])

# %%
sns.distplot(df["AveRooms"]) #a very small amount of skewed data are there

# %%
sns.distplot(df["AveOccup"])

# %%
#distribution plot for Latitude
sns.distplot(df["Latitude"])  #no skewed data present

# %%
#distribution plot for Longitude
sns.distplot(df["Longitude"])  #no skewed data present

# %%
#visualization with boxplot
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,figsize=(15,15))
plt.tight_layout()   #plotting for checking outliers

# %%
#find the correlation matrix with visualization
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)  #most of the data are mildly corelated

# %%
#removing outliers
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
#shape changed from 20640,9 to 19794,9
# Out:
# (20640, 9)
# (19794, 9)

# %%
#checking skewness
df_new.skew()  #skewed data present
# Out:
# MedInc        0.786048
# HouseAge      0.046496
# AveRooms      0.555865
# AveBedrms     3.913734
# Population    1.346151
# AveOccup      5.789707
# Latitude      0.460162
# Longitude    -0.292814
# target        0.970197
# dtype: float64

# %%
#removing skewness
import numpy as np
for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
#again checking for skewness
df_new.skew()
# Out:
# MedInc       -0.046003
# HouseAge      0.046496
# AveRooms     -0.303532
# AveBedrms     2.880437
# Population   -1.281355
# AveOccup      0.801586
# Latitude      0.460162
# Longitude    -0.292814
# target        0.255509
# dtype: float64

# %%
#let separate input and output variables to be used for the problem
x=df_new.drop(columns=['target'])
x=pd.DataFrame(df_new.iloc[:,0:-1])
y=pd.DataFrame(df_new['target'])

# %%
#Using standardscaler tecnique for scaling the data

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
y=df_new.iloc[:,-1]
y.head()
# Out:
# 0    1.709464
# 1    1.522790
# 2    1.508733
# 3    1.484555
# 4    1.486592
# Name: target, dtype: float64

# %% [markdown]
# For this dataset we have to use Regression Algorithm

# %%
#Using Linear Regression:

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
def maxr2_score(regr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        regr=linear_model.LinearRegression()
        regr.fit(x_train,y_train)
        y_predict=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
regr=linear_model.LinearRegression()
r_state=maxr2_score(regr,x,y)
# Out:
# r2score corresponing to 42 is: 0.6472348273153963
# r2score corresponing to 43 is: 0.6652680687294256
# r2score corresponing to 44 is: 0.6761128500942784
# r2score corresponing to 45 is: 0.6812936273946169
# r2score corresponing to 46 is: 0.6718132811479105
# r2score corresponing to 47 is: 0.6561250577753118
# r2score corresponing to 48 is: 0.7003200108624179
# r2score corresponing to 49 is: 0.6690943602751893
# r2score corresponing to 50 is: 0.6681220683979641
# r2score corresponing to 51 is: 0.6562931075048262
# r2score corresponing to 52 is: 0.6528464640674845
# r2score corresponing to 53 is: 0.6518765364452792
# r2score corresponing to 54 is: 0.6606356157842006
# r2score corresponing to 55 is: 0.6773655186123836
# r2score corresponing to 56 is: 0.6700722468788753
# r2score corresponing to 57 is: 0.6615245026435204
# r2score corresponing to 58 is: 0.6854192075694887
# r2score corresponing to 59 is: 0.6876126005839485
# r2score corresponing to 60 is: 0.6731190219327183
# r2score corresponing to 61 is: 0.6576698008218227
# r2score corresponing to 62 is: 0.6731669582917498
# r2score corresponing to 63 is: 0.6632420481255055
# r2score corresponing to 64 is: 0.6776507067743293
# r2score corresponing to 65 is: 0.6592139275361946
# r2score corresponing to 66 is: 0.677949382034045
# r2score corresponing to 67 is: 0.6616620581965882
# r2score corresponing to 68 is: 0.6648311506906841
# r2score corresponing to 69 is: 0.6622582109300601
# r2score corresponing to 70 is: 0.6656654135997737
# r2score corresponing to 71 is: 0.6654446541275755
# r2score corresponing to 72 is: 0.6817042891835154
# r2score corresponing to 73 is: 0.6695264652181911
# r2score corresponing to 74 is: 0.6679936457529898
# r2score corresponing to 75 is: 0.6547231559122852
# r2score corresponing to 76 is: 0.6639364470669076
# r2score corresponing to 77 is: 0.6659080441714997
# r2score corresponing to 78 is: 0.6615157462038284
# r2score corresponing to 79 is: 0.6554823230285338
# r2score corresponing to 80 is: 0.6692562548922238
# r2score corresponing to 81 is: 0.675172037720712
# r2score corresponing to 82 is: 0.6626440623219576
# r2score corresponing to 83 is: 0.6703243937267045
# r2score corresponing to 84 is: 0.6712957863213225
# r2score corresponing to 85 is: 0.6773179492546282
# r2score corresponing to 86 is: 0.6517666701837788
# r2score corresponing to 87 is: 0.659515775087407
# r2score corresponing to 88 is: 0.654391408613453
# r2score corresponing to 89 is: 0.6610547274004638
# r2score corresponing to 90 is: 0.6682173411520792
# r2score corresponing to 91 is: 0.652801601816341
# r2score corresponing to 92 is: 0.6800194630613234
# r2score corresponing to 93 is: 0.6750345844563576
# r2score corresponing to 94 is: 0.6491624674495349
# r2score corresponing to 95 is: 0.6733961151512304
# r2score corresponing to 96 is: 0.6665779780218739
# r2score corresponing to 97 is: 0.6598134733239511
# r2score corresponing to 98 is: 0.6620711981738197
# r2score corresponing to 99 is: 0.6554171153949551
# r2score corresponing to 100 is: 0.6678656229069444
#
#
# max r2_score corresponding to  48 is 0.7003200108624179

# %%
#Using GridSearchCV for finding best parameters
from sklearn.model_selection import GridSearchCV

# %%
#for KNR:
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,25)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 15}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(knr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=15)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
knr=KNeighborsRegressor(n_neighbors=15)
r_state=maxr2_score(knr,x,y)
# Out:
# r2score corresponing to 42 is: 0.7335047917020217
# r2score corresponing to 43 is: 0.7365914564307153
# r2score corresponing to 44 is: 0.7379640006271069
# r2score corresponing to 45 is: 0.7376611347534809
# r2score corresponing to 46 is: 0.7286819490335374
# r2score corresponing to 47 is: 0.7363867699367841
# r2score corresponing to 48 is: 0.7561128031863019
# r2score corresponing to 49 is: 0.7391970429393863
# r2score corresponing to 50 is: 0.7336737828060711
# r2score corresponing to 51 is: 0.7212985444135926
# r2score corresponing to 52 is: 0.736820243451832
# r2score corresponing to 53 is: 0.7224334447738235
# r2score corresponing to 54 is: 0.7295051510340695
# r2score corresponing to 55 is: 0.7541883244166487
# r2score corresponing to 56 is: 0.7462831322986554
# r2score corresponing to 57 is: 0.74373243020081
# r2score corresponing to 58 is: 0.7513651920299587
# r2score corresponing to 59 is: 0.7508719917971565
# r2score corresponing to 60 is: 0.7489564829673825
# r2score corresponing to 61 is: 0.7342127353605439
# r2score corresponing to 62 is: 0.7381681014966531
# r2score corresponing to 63 is: 0.729154074185157
# r2score corresponing to 64 is: 0.7412535609105688
# r2score corresponing to 65 is: 0.7300013140283488
# r2score corresponing to 66 is: 0.7359672703555448
# r2score corresponing to 67 is: 0.7384566837071678
# r2score corresponing to 68 is: 0.727077175743833
# r2score corresponing to 69 is: 0.7302199269229289
# r2score corresponing to 70 is: 0.7388912550525946
# r2score corresponing to 71 is: 0.7402820970048738
# r2score corresponing to 72 is: 0.7437206554502986
# r2score corresponing to 73 is: 0.7322424835226233
# r2score corresponing to 74 is: 0.7334865441249938
# r2score corresponing to 75 is: 0.731660858910314
# r2score corresponing to 76 is: 0.7382507077516843
# r2score corresponing to 77 is: 0.7346483166225333
# r2score corresponing to 78 is: 0.7289407442699078
# r2score corresponing to 79 is: 0.7315547131919744
# r2score corresponing to 80 is: 0.7390878432554319
# r2score corresponing to 81 is: 0.7373759280291698
# r2score corresponing to 82 is: 0.7298403792983457
# r2score corresponing to 83 is: 0.747265481724155
# r2score corresponing to 84 is: 0.7408341196534186
# r2score corresponing to 85 is: 0.7408446848564839
# r2score corresponing to 86 is: 0.7294437451481047
# r2score corresponing to 87 is: 0.73543927873182
# r2score corresponing to 88 is: 0.7324288364151506
# r2score corresponing to 89 is: 0.733573961558551
# r2score corresponing to 90 is: 0.7330395521016666
# r2score corresponing to 91 is: 0.732168431397398
# r2score corresponing to 92 is: 0.7405421414650502
# r2score corresponing to 93 is: 0.7359797890764281
# r2score corresponing to 94 is: 0.718208752213976
# r2score corresponing to 95 is: 0.7408400808334512
# r2score corresponing to 96 is: 0.7414052472512318
# r2score corresponing to 97 is: 0.7319103295697795
# r2score corresponing to 98 is: 0.7275183053279642
# r2score corresponing to 99 is: 0.7322948601404274
# r2score corresponing to 100 is: 0.737693143513606
#
#
# max r2_score corresponding to  48 is 0.7561128031863019

# %%
#find best parameter for DCT:
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'random_state': 0}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(dtr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=0)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
dtr=DecisionTreeRegressor(random_state=0)
r_state=maxr2_score(dtr,x,y)
# Out:
# r2score corresponing to 42 is: 0.6384953199705905
# r2score corresponing to 43 is: 0.6167998402341716
# r2score corresponing to 44 is: 0.6247320657929446
# r2score corresponing to 45 is: 0.6490254731773977
# r2score corresponing to 46 is: 0.6482296263879135
# r2score corresponing to 47 is: 0.6115108501268378
# r2score corresponing to 48 is: 0.67411878851508
# r2score corresponing to 49 is: 0.6204345737619846
# r2score corresponing to 50 is: 0.6219337603444008
# r2score corresponing to 51 is: 0.6130992191137581
# r2score corresponing to 52 is: 0.6141765222699314
# r2score corresponing to 53 is: 0.6191337897594041
# r2score corresponing to 54 is: 0.6471441121629949
# r2score corresponing to 55 is: 0.6625569128074106
# r2score corresponing to 56 is: 0.6268285326581292
# r2score corresponing to 57 is: 0.6218476615260429
# r2score corresponing to 58 is: 0.6290081700221906
# r2score corresponing to 59 is: 0.6553545113924524
# r2score corresponing to 60 is: 0.6437719885895294
# r2score corresponing to 61 is: 0.6094219352049157
# r2score corresponing to 62 is: 0.6317292437699058
# r2score corresponing to 63 is: 0.6300398018972798
# r2score corresponing to 64 is: 0.6452957038182214
# r2score corresponing to 65 is: 0.6061508266264559
# r2score corresponing to 66 is: 0.6229961322977551
# r2score corresponing to 67 is: 0.6469263783298057
# r2score corresponing to 68 is: 0.6340576125354486
# r2score corresponing to 69 is: 0.6188215082190227
# r2score corresponing to 70 is: 0.6460045891287318
# r2score corresponing to 71 is: 0.6370464847109992
# r2score corresponing to 72 is: 0.6368271012714622
# r2score corresponing to 73 is: 0.6225163079289344
# r2score corresponing to 74 is: 0.6293883682805137
# r2score corresponing to 75 is: 0.6209368477535466
# r2score corresponing to 76 is: 0.6332233752636554
# r2score corresponing to 77 is: 0.6245071157812654
# r2score corresponing to 78 is: 0.6370190849129579
# r2score corresponing to 79 is: 0.6166727310379965
# r2score corresponing to 80 is: 0.63607512814741
# r2score corresponing to 81 is: 0.6252382611266576
# r2score corresponing to 82 is: 0.6457302846549249
# r2score corresponing to 83 is: 0.6450219104470523
# r2score corresponing to 84 is: 0.6218788187356702
# r2score corresponing to 85 is: 0.6263967575284637
# r2score corresponing to 86 is: 0.6348105996220725
# r2score corresponing to 87 is: 0.6172142140695156
# r2score corresponing to 88 is: 0.621265354712344
# r2score corresponing to 89 is: 0.6231097088334869
# r2score corresponing to 90 is: 0.6459016088781815
# r2score corresponing to 91 is: 0.6361904989932824
# r2score corresponing to 92 is: 0.6359747653546455
# r2score corresponing to 93 is: 0.6268529937207297
# r2score corresponing to 94 is: 0.6311219049022836
# r2score corresponing to 95 is: 0.6728545334458321
# r2score corresponing to 96 is: 0.641301236736508
# r2score corresponing to 97 is: 0.645243488849464
# r2score corresponing to 98 is: 0.6001092186443939
# r2score corresponing to 99 is: 0.6348384239193683
# r2score corresponing to 100 is: 0.6400903305630142
#
#
# max r2_score corresponding to  48 is 0.67411878851508

# %%
#find best parameter for SVR:
from sklearn.svm import SVR
sv=SVR()
parameters={"kernel":['linear','poly','rbf']}
clf=GridSearchCV(sv,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(sv,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        sv=SVR(kernel="rbf")
        sv.fit(x_train,y_train)
        y_predict=sv.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
sv=SVR(kernel="rbf")
r_state=maxr2_score(sv,x,y)
# Out:
# r2score corresponing to 42 is: 0.7775497529452399
# r2score corresponing to 43 is: 0.785614744417995
# r2score corresponing to 44 is: 0.7891894819579923
# r2score corresponing to 45 is: 0.7889998014095363
# r2score corresponing to 46 is: 0.7834668462563261
# r2score corresponing to 47 is: 0.7955425595381342
# r2score corresponing to 48 is: 0.8089906962991484
# r2score corresponing to 49 is: 0.7844650577022323
# r2score corresponing to 50 is: 0.7834938124164196
# r2score corresponing to 51 is: 0.7769643352949871
# r2score corresponing to 52 is: 0.7833912477722155
# r2score corresponing to 53 is: 0.7765383064263276
# r2score corresponing to 54 is: 0.7833519244075574
# r2score corresponing to 55 is: 0.8008170725877359
# r2score corresponing to 56 is: 0.789661305398675
# r2score corresponing to 57 is: 0.7909748469698731
# r2score corresponing to 58 is: 0.797607643595568
# r2score corresponing to 59 is: 0.7966430759253222
# r2score corresponing to 60 is: 0.7892582599238143
# r2score corresponing to 61 is: 0.7820822448258584
# r2score corresponing to 62 is: 0.7943435907819774
# r2score corresponing to 63 is: 0.7847656597943946
# r2score corresponing to 64 is: 0.7954473452368451
# r2score corresponing to 65 is: 0.7801546210942635
# r2score corresponing to 66 is: 0.7854681559852085
# r2score corresponing to 67 is: 0.7898289798536489
# r2score corresponing to 68 is: 0.7827468329745118
# r2score corresponing to 69 is: 0.7763834976882106
# r2score corresponing to 70 is: 0.77817386436052
# r2score corresponing to 71 is: 0.7860139974691274
# r2score corresponing to 72 is: 0.7898691999517429
# r2score corresponing to 73 is: 0.7774456462967959
# r2score corresponing to 74 is: 0.7892860340573202
# r2score corresponing to 75 is: 0.7873880238814934
# r2score corresponing to 76 is: 0.7852896509325866
# r2score corresponing to 77 is: 0.7873970740209937
# r2score corresponing to 78 is: 0.7834060951456617
# r2score corresponing to 79 is: 0.7796424036092875
# r2score corresponing to 80 is: 0.788336400698552
# r2score corresponing to 81 is: 0.7934522332157501
# r2score corresponing to 82 is: 0.7772997386010461
# r2score corresponing to 83 is: 0.7907999221462643
# r2score corresponing to 84 is: 0.7901813981131686
# r2score corresponing to 85 is: 0.7880231325179923
# r2score corresponing to 86 is: 0.7859101490212881
# r2score corresponing to 87 is: 0.7867609088203112
# r2score corresponing to 88 is: 0.7828207618649752
# r2score corresponing to 89 is: 0.7853909695711966
# r2score corresponing to 90 is: 0.7880928639769993
# r2score corresponing to 91 is: 0.7817274236005735
# r2score corresponing to 92 is: 0.78651189404446
# r2score corresponing to 93 is: 0.7803458126153562
# r2score corresponing to 94 is: 0.7671038018949246
# r2score corresponing to 95 is: 0.7915509973718249
# r2score corresponing to 96 is: 0.7872120024158128
# r2score corresponing to 97 is: 0.7859069950923023
# r2score corresponing to 98 is: 0.7858036644222798
# r2score corresponing to 99 is: 0.7873035995812616
# r2score corresponing to 100 is: 0.7877576949464953
#
#
# max r2_score corresponding to  48 is 0.8089906962991484

# %%
#cross validation using cross val score
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(regr,x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(regr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
print('\n')
knr_score_mean=cross_val_score(knr,x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
print('\n')
dtr_score_mean=cross_val_score(dtr,x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of DecisionTreeRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
print('\n')
sv_score_mean=cross_val_score(sv,x,y,cv=5,scoring="r2").mean()
sv_score_std=cross_val_score(sv,x,y,cv=5,scoring="r2").std()
print("mean r2 score of SVR :",sv_score_mean)
print("stadard deviation for r2 score of SVR :",sv_score_std)
# Out:
# mean r2 score of linearRegression : 0.6012566771487052
# stadard deviation for r2 score of linearRegression : 0.07782411804868389
#
#
# mean r2 score of knr: 0.6026370654988092
# standard deviation of r2score for knr: 0.0580110969749155
#
#
# mean r2 score of DecisionTreeRegression : 0.3153315338092278
# stadard deviation for r2 score of DecisionTreeeRegression : 0.10240302357793529
#
#
# mean r2 score of SVR : 0.6754399618751848
# stadard deviation for r2 score of SVR : 0.06191179227837892

# %%
#best parameter for Ridge Operation:
from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(r_reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling Ridge function
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.6472430423070369
# r2score corresponing to 43 is: 0.665270369732166
# r2score corresponing to 44 is: 0.6761027581333396
# r2score corresponing to 45 is: 0.6812835722596297
# r2score corresponing to 46 is: 0.6718089159275271
# r2score corresponing to 47 is: 0.6561258079374681
# r2score corresponing to 48 is: 0.7003149923504749
# r2score corresponing to 49 is: 0.669097841692668
# r2score corresponing to 50 is: 0.6681122982745065
# r2score corresponing to 51 is: 0.6562905628491449
# r2score corresponing to 52 is: 0.652843241838476
# r2score corresponing to 53 is: 0.6518804970623476
# r2score corresponing to 54 is: 0.6606307767492332
# r2score corresponing to 55 is: 0.6773726439819916
# r2score corresponing to 56 is: 0.6700792873637689
# r2score corresponing to 57 is: 0.6615368477198251
# r2score corresponing to 58 is: 0.6854180061304123
# r2score corresponing to 59 is: 0.68761893097756
# r2score corresponing to 60 is: 0.6731232154469542
# r2score corresponing to 61 is: 0.657676398410809
# r2score corresponing to 62 is: 0.673163485921276
# r2score corresponing to 63 is: 0.6632401655736977
# r2score corresponing to 64 is: 0.6776490247519175
# r2score corresponing to 65 is: 0.6592088055244663
# r2score corresponing to 66 is: 0.6779404071489528
# r2score corresponing to 67 is: 0.6616638249886266
# r2score corresponing to 68 is: 0.6648249928090855
# r2score corresponing to 69 is: 0.6622560966030311
# r2score corresponing to 70 is: 0.6656660498989905
# r2score corresponing to 71 is: 0.6654472095323366
# r2score corresponing to 72 is: 0.681699220371272
# r2score corresponing to 73 is: 0.6695269302163869
# r2score corresponing to 74 is: 0.6679907513868273
# r2score corresponing to 75 is: 0.6547245190031017
# r2score corresponing to 76 is: 0.6639493654582026
# r2score corresponing to 77 is: 0.6659199156769273
# r2score corresponing to 78 is: 0.661503569198763
# r2score corresponing to 79 is: 0.6554900976283136
# r2score corresponing to 80 is: 0.6692584992607833
# r2score corresponing to 81 is: 0.6751716432627443
# r2score corresponing to 82 is: 0.662651875506034
# r2score corresponing to 83 is: 0.6703298291893568
# r2score corresponing to 84 is: 0.6713028788374231
# r2score corresponing to 85 is: 0.6773151702653266
# r2score corresponing to 86 is: 0.6517520082602464
# r2score corresponing to 87 is: 0.6595333519854363
# r2score corresponing to 88 is: 0.6543885576605939
# r2score corresponing to 89 is: 0.6610572028229124
# r2score corresponing to 90 is: 0.6682044196449856
# r2score corresponing to 91 is: 0.6527988472239226
# r2score corresponing to 92 is: 0.6800121104935615
# r2score corresponing to 93 is: 0.6750369459137607
# r2score corresponing to 94 is: 0.6491651462664529
# r2score corresponing to 95 is: 0.673394629983793
# r2score corresponing to 96 is: 0.6665888401091805
# r2score corresponing to 97 is: 0.6598067192629575
# r2score corresponing to 98 is: 0.6620657009280382
# r2score corresponing to 99 is: 0.65541375144776
# r2score corresponing to 100 is: 0.6678744607057181
#
#
# max r2_score corresponding to  48 is 0.7003149923504749

# %%
#cross validation using cross val score
r_reg_score_mean=cross_val_score(r_reg,x,y,cv=5,scoring="r2").mean()
r_reg_score_std=cross_val_score(r_reg,x,y,cv=5,scoring="r2").std()
print("mean r2score for RidgeRegression:",r_reg_score_mean)
print("standard deviation in r2score for RidgeRegression:",r_reg_score_std)
# Out:
# mean r2score for RidgeRegression: 0.601258323784579
# standard deviation in r2score for RidgeRegression: 0.0778270186925424

# %%
#Parameters  for Lasso Operation
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.001}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(lsreg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=0.001)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling lasso function
lsreg=Lasso(alpha=0.001)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2score corresponing to 42 is: 0.6476246410901028
# r2score corresponing to 43 is: 0.6653514906006006
# r2score corresponing to 44 is: 0.6752455578846202
# r2score corresponing to 45 is: 0.6804004416081266
# r2score corresponing to 46 is: 0.6714554658780421
# r2score corresponing to 47 is: 0.6560458509461476
# r2score corresponing to 48 is: 0.699628519964767
# r2score corresponing to 49 is: 0.6690478795087191
# r2score corresponing to 50 is: 0.6677136662859984
# r2score corresponing to 51 is: 0.6558952336026065
# r2score corresponing to 52 is: 0.6527890416726854
# r2score corresponing to 53 is: 0.6520217996118965
# r2score corresponing to 54 is: 0.6605998842656381
# r2score corresponing to 55 is: 0.6773090724750841
# r2score corresponing to 56 is: 0.6703122735377642
# r2score corresponing to 57 is: 0.6616201092705538
# r2score corresponing to 58 is: 0.6850253863128758
# r2score corresponing to 59 is: 0.6869840596548564
# r2score corresponing to 60 is: 0.6730181203259763
# r2score corresponing to 61 is: 0.6578757225177734
# r2score corresponing to 62 is: 0.6725854191732223
# r2score corresponing to 63 is: 0.6628373551304507
# r2score corresponing to 64 is: 0.6771350374020665
# r2score corresponing to 65 is: 0.659030598231646
# r2score corresponing to 66 is: 0.6770678489108802
# r2score corresponing to 67 is: 0.6615745187441802
# r2score corresponing to 68 is: 0.6641677061416369
# r2score corresponing to 69 is: 0.6619184232063464
# r2score corresponing to 70 is: 0.6654324119651236
# r2score corresponing to 71 is: 0.6651171914422764
# r2score corresponing to 72 is: 0.6812287263114918
# r2score corresponing to 73 is: 0.6693069230420781
# r2score corresponing to 74 is: 0.6675090077663504
# r2score corresponing to 75 is: 0.6547167540671344
# r2score corresponing to 76 is: 0.6641913365407884
# r2score corresponing to 77 is: 0.6664430600950906
# r2score corresponing to 78 is: 0.6607801597810883
# r2score corresponing to 79 is: 0.655409882077022
# r2score corresponing to 80 is: 0.6691735303187603
# r2score corresponing to 81 is: 0.6749051254514716
# r2score corresponing to 82 is: 0.6629817457506901
# r2score corresponing to 83 is: 0.6701699921043873
# r2score corresponing to 84 is: 0.6710728239191366
# r2score corresponing to 85 is: 0.6772249381935092
# r2score corresponing to 86 is: 0.650742893875109
# r2score corresponing to 87 is: 0.6598341584551396
# r2score corresponing to 88 is: 0.6542935282056936
# r2score corresponing to 89 is: 0.6609719257360125
# r2score corresponing to 90 is: 0.667573722410751
# r2score corresponing to 91 is: 0.6527085724899098
# r2score corresponing to 92 is: 0.6793560311532161
# r2score corresponing to 93 is: 0.6749402824770512
# r2score corresponing to 94 is: 0.6492762276405486
# r2score corresponing to 95 is: 0.6731945573324467
# r2score corresponing to 96 is: 0.6667398526041621
# r2score corresponing to 97 is: 0.6589501196952277
# r2score corresponing to 98 is: 0.6613733546473748
# r2score corresponing to 99 is: 0.6547576157804751
# r2score corresponing to 100 is: 0.6679976764698259
#
#
# max r2_score corresponding to  48 is 0.699628519964767

# %%
#cross validation using cross val score
Lsreg_score_mean=cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
# Out:
# mean r2score for Lasso: 0.5997729864352491
# standard deviation in r2score for lasso: 0.07965925663249133

# %%
#Find best parameter for GradientBoosting:
from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(gbr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.1, n_estimators=500)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
gbr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=500)
r_state=maxr2_score(gbr,x,y)
# Out:
# r2score corresponing to 42 is: 0.8296836276176321
# r2score corresponing to 43 is: 0.8298024002439625
# r2score corresponing to 44 is: 0.8320991559984936
# r2score corresponing to 45 is: 0.8337660791095947
# r2score corresponing to 46 is: 0.8350501460899197
# r2score corresponing to 47 is: 0.8315856230094476
# r2score corresponing to 48 is: 0.851621449134676
# r2score corresponing to 49 is: 0.8343267214906114
# r2score corresponing to 50 is: 0.8318937066586458
# r2score corresponing to 51 is: 0.831932036222592
# r2score corresponing to 52 is: 0.8368969401514016
# r2score corresponing to 53 is: 0.8306399290051991
# r2score corresponing to 54 is: 0.8235462869516507
# r2score corresponing to 55 is: 0.8454132888780863
# r2score corresponing to 56 is: 0.8402788071397582
# r2score corresponing to 57 is: 0.834259901424147
# r2score corresponing to 58 is: 0.8502125283367112
# r2score corresponing to 59 is: 0.8435003687069249
# r2score corresponing to 60 is: 0.8436005826899644
# r2score corresponing to 61 is: 0.8331493505617928
# r2score corresponing to 62 is: 0.8417753915471202
# r2score corresponing to 63 is: 0.8358498458249111
# r2score corresponing to 64 is: 0.8482273497738955
# r2score corresponing to 65 is: 0.8296810673818243
# r2score corresponing to 66 is: 0.8386945335786516
# r2score corresponing to 67 is: 0.8359981835960545
# r2score corresponing to 68 is: 0.8331071334252815
# r2score corresponing to 69 is: 0.8296574530130583
# r2score corresponing to 70 is: 0.830892577790644
# r2score corresponing to 71 is: 0.836978524455145
# r2score corresponing to 72 is: 0.8371578748834653
# r2score corresponing to 73 is: 0.8309716471633617
# r2score corresponing to 74 is: 0.8368604182324184
# r2score corresponing to 75 is: 0.8328662684799545
# r2score corresponing to 76 is: 0.834670197009631
# r2score corresponing to 77 is: 0.8364434577841355
# r2score corresponing to 78 is: 0.8326813604790457
# r2score corresponing to 79 is: 0.8317279971303755
# r2score corresponing to 80 is: 0.8367420260412305
# r2score corresponing to 81 is: 0.8343866558519097
# r2score corresponing to 82 is: 0.8201096703101655
# r2score corresponing to 83 is: 0.8441160336824403
# r2score corresponing to 84 is: 0.8350851019281936
# r2score corresponing to 85 is: 0.8325764032436466
# r2score corresponing to 86 is: 0.831245450521329
# r2score corresponing to 87 is: 0.8367539229820622
# r2score corresponing to 88 is: 0.837970178643325
# r2score corresponing to 89 is: 0.8324359056677234
# r2score corresponing to 90 is: 0.830409553003073
# r2score corresponing to 91 is: 0.8337499367447637
# r2score corresponing to 92 is: 0.8375129502316113
# r2score corresponing to 93 is: 0.8354794078333024
# r2score corresponing to 94 is: 0.8253855244672617
# r2score corresponing to 95 is: 0.8383903834171957
# r2score corresponing to 96 is: 0.8352611456104311
# r2score corresponing to 97 is: 0.8361362187880055
# r2score corresponing to 98 is: 0.8344848493061918
# r2score corresponing to 99 is: 0.8345572756103078
# r2score corresponing to 100 is: 0.839809100709075
#
#
# max r2_score corresponding to  48 is 0.851621449134676

# %%
#cross validation using cross val score
gbr_score_mean=cross_val_score(gbr,x,y,cv=5,scoring="r2").mean()
gbr_score_std=cross_val_score(gbr,x,y,cv=5,scoring="r2").std()
print("mean r2score for GradientBoostRegression:",gbr_score_mean)
print("standard deviation in r2score for GradientBoostRegression:",gbr_score_std)
# Out:
# mean r2score for GradientBoostRegression: 0.6862755518266231
# standard deviation in r2score for GradientBoostRegression: 0.032936050563084636

# %%
#Find best parameters for AdaBoostRegressor:
from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[regr,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 100}

# %%
#creating a function to find the maximum r2score corresponding to random state
def maxr2_score(ada_reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 100)
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
ada_reg=AdaBoostRegressor(base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
                       max_leaf_nodes=None, min_impurity_decrease=0.0,
                       min_impurity_split=None, min_samples_leaf=1,
                       min_samples_split=2, min_weight_fraction_leaf=0.0,
                       presort=False, random_state=None, splitter='best'),
 learning_rate= 1,
 n_estimators= 100)
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.8337539481502223
# r2score corresponing to 43 is: 0.8381966012519375
# r2score corresponing to 44 is: 0.8384527199017378
# r2score corresponing to 45 is: 0.8418379943021101
# r2score corresponing to 46 is: 0.8368533343156741
# r2score corresponing to 47 is: 0.8341650669472
# r2score corresponing to 48 is: 0.8541533942250068
# r2score corresponing to 49 is: 0.8447050450579454
# r2score corresponing to 50 is: 0.8372285627562395
# r2score corresponing to 51 is: 0.8368538323053457
# r2score corresponing to 52 is: 0.8417333274163531
# r2score corresponing to 53 is: 0.8326650977524805
# r2score corresponing to 54 is: 0.8332684838742183
# r2score corresponing to 55 is: 0.8466256856307615
# r2score corresponing to 56 is: 0.8489508218441242
# r2score corresponing to 57 is: 0.8404329421210769
# r2score corresponing to 58 is: 0.8501697392271028
# r2score corresponing to 59 is: 0.8499066793234058
# r2score corresponing to 60 is: 0.8461558626381297
# r2score corresponing to 61 is: 0.8384053821625896
# r2score corresponing to 62 is: 0.843081735613366
# r2score corresponing to 63 is: 0.8380803213929787
# r2score corresponing to 64 is: 0.8537478011498487
# r2score corresponing to 65 is: 0.8269645008807429
# r2score corresponing to 66 is: 0.8446095226996286
# r2score corresponing to 67 is: 0.8373267654228379
# r2score corresponing to 68 is: 0.8417691145017969
# r2score corresponing to 69 is: 0.8306987157748043
# r2score corresponing to 70 is: 0.8408912610716117
# r2score corresponing to 71 is: 0.8384778555369197
# r2score corresponing to 72 is: 0.836827216130278
# r2score corresponing to 73 is: 0.8329062245247962
# r2score corresponing to 74 is: 0.8407797220811679
# r2score corresponing to 75 is: 0.8376028216767601
# r2score corresponing to 76 is: 0.8429112394606939
# r2score corresponing to 77 is: 0.839040298524748
# r2score corresponing to 78 is: 0.8416122770841077
# r2score corresponing to 79 is: 0.8390682638426472
# r2score corresponing to 80 is: 0.8398613741104797
# r2score corresponing to 81 is: 0.8382046127528595
# r2score corresponing to 82 is: 0.8331617280540466
# r2score corresponing to 83 is: 0.8444666532384376
# r2score corresponing to 84 is: 0.8407211336976249
# r2score corresponing to 85 is: 0.8301779266861862
# r2score corresponing to 86 is: 0.8341333644390304
# r2score corresponing to 87 is: 0.8444952842134268
# r2score corresponing to 88 is: 0.8417334789481181
# r2score corresponing to 89 is: 0.837385422075778
# r2score corresponing to 90 is: 0.834290993652256
# r2score corresponing to 91 is: 0.8336435632572314
# r2score corresponing to 92 is: 0.8445640757471136
# r2score corresponing to 93 is: 0.8468413542668581
# r2score corresponing to 94 is: 0.8230143268703982
# r2score corresponing to 95 is: 0.84260659017326
# r2score corresponing to 96 is: 0.8393243987080603
# r2score corresponing to 97 is: 0.8433173334832123
# r2score corresponing to 98 is: 0.8374034346227386
# r2score corresponing to 99 is: 0.837694767916829
# r2score corresponing to 100 is: 0.8410170339209686
#
#
# max r2_score corresponding to  48 is 0.8541533942250068

# %%
#cross validation using cross val score
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# mean r2score for AdaBoostRegressor: 0.6433457294438705
# standard deviationof  r2score for AdaBoostRegressor: 0.0652203281496778

# %% [markdown]
# #since AdaBoostRegressor provides an r2score of 0.8541 at random_state 48 so choosing the parameters to divide the data and then fit it with AdaboostRegressor and predicting the values.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=48,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)

# %%
print("r2score is",r2_score(y_test,y_pred))
print("root mean squared error is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2score is 0.8526016989216676
# root mean squared error is 0.13542670665940032

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(ada_reg,"adareg_CaliHouse.pkl")
# Out:
# ['adareg_CaliHouse.pkl']

# %%
#load the model
model=joblib.load('adareg_CaliHouse.pkl')
