# %%
#importing pandas library
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset
avocado=pd.read_csv('avocado.csv',parse_dates=['Date'])
avocado
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 0              0 2015-12-27          1.33      64236.62     1036.74
# 1              1 2015-12-20          1.35      54876.98      674.28
# 2              2 2015-12-13          0.93     118220.22      794.70
# 3              3 2015-06-12          1.08      78992.15     1132.00
# 4              4 2015-11-29          1.28      51039.60      941.48
# 5              5 2015-11-22          1.26      55979.78     1184.27
# 6              6 2015-11-15          0.99      83453.76     1368.92
# 7              7 2015-08-11          0.98     109428.33      703.75
# 8              8 2015-01-11          1.02      99811.42     1022.15
# 9              9 2015-10-25          1.07      74338.76      842.40
# 10            10 2015-10-18          1.12      84843.44      924.86
# 11            11 2015-11-10          1.28      64489.17     1582.03
# 12            12 2015-04-10          1.31      61007.10     2268.32
# ...

# %%
#drop the column
avocado.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#view the dataset
avocado
# Out:
#            Date  AveragePrice  Total Volume        4046        4225  \
# 0    2015-12-27          1.33      64236.62     1036.74    54454.85
# 1    2015-12-20          1.35      54876.98      674.28    44638.81
# 2    2015-12-13          0.93     118220.22      794.70   109149.67
# 3    2015-06-12          1.08      78992.15     1132.00    71976.41
# 4    2015-11-29          1.28      51039.60      941.48    43838.39
# 5    2015-11-22          1.26      55979.78     1184.27    48067.99
# 6    2015-11-15          0.99      83453.76     1368.92    73672.72
# 7    2015-08-11          0.98     109428.33      703.75   101815.36
# 8    2015-01-11          1.02      99811.42     1022.15    87315.57
# 9    2015-10-25          1.07      74338.76      842.40    64757.44
# 10   2015-10-18          1.12      84843.44      924.86    75595.85
# 11   2015-11-10          1.28      64489.17     1582.03    52677.92
# 12   2015-04-10          1.31      61007.10     2268.32    49880.67
# ...

# %%
#shape of the dataset
avocado.shape
# Out:
# (1517, 13)

# %%
#check the datatypes
avocado.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
#checking information
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
# Date            1517 non-null datetime64[ns]
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 154.1+ KB

# %%
#check all the columns
avocado.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
#find statistical information of each column
avocado.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
#checking whether there is a null value or not?
avocado.isnull().sum()   #no null data present
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#checking null values with visualization
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(avocado.isnull())   #no null data present

# %%
#from date we can get monthly,daily,yearly averageprice of avocado
avocado_dates=pd.DataFrame()
avocado_dates['month']=avocado['Date'].dt.month_name()
avocado_dates['year']=avocado['Date'].dt.year
avocado_dates['day']=avocado['Date'].dt.day_name()
avocado_dates['AveragePrice']=avocado['AveragePrice']
avocado_dates
# Out:
#           month  year        day  AveragePrice
# 0      December  2015     Sunday          1.33
# 1      December  2015     Sunday          1.35
# 2      December  2015     Sunday          0.93
# 3          June  2015     Friday          1.08
# 4      November  2015     Sunday          1.28
# 5      November  2015     Sunday          1.26
# 6      November  2015     Sunday          0.99
# 7        August  2015    Tuesday          0.98
# 8       January  2015     Sunday          1.02
# 9       October  2015     Sunday          1.07
# 10      October  2015     Sunday          1.12
# 11     November  2015    Tuesday          1.28
# 12        April  2015     Friday          1.31
# 13    September  2015     Sunday          0.99
# 14    September  2015     Sunday          1.33
# 15    September  2015     Sunday          1.28
# 16         June  2015    Tuesday          1.11
# 17       August  2015     Sunday          1.07
# 18       August  2015     Sunday          1.34
# ...

# %%
#checking for distinct year
avocado_dates['year'].drop_duplicates()
# Out:
# 0       2015
# 1270    2016
# Name: year, dtype: int64

# %%
#making another column which tells whether it is weekday or weekend
import numpy as np
avocado_dates['type_of_day']=np.where((avocado_dates['day']=='Sunday')|(avocado_dates['day']=='Saturday'),'weekend','weekday')

# %%
avocado_dates
# Out:
#           month  year        day  AveragePrice type_of_day
# 0      December  2015     Sunday          1.33     weekend
# 1      December  2015     Sunday          1.35     weekend
# 2      December  2015     Sunday          0.93     weekend
# 3          June  2015     Friday          1.08     weekday
# 4      November  2015     Sunday          1.28     weekend
# 5      November  2015     Sunday          1.26     weekend
# 6      November  2015     Sunday          0.99     weekend
# 7        August  2015    Tuesday          0.98     weekday
# 8       January  2015     Sunday          1.02     weekend
# 9       October  2015     Sunday          1.07     weekend
# 10      October  2015     Sunday          1.12     weekend
# 11     November  2015    Tuesday          1.28     weekday
# 12        April  2015     Friday          1.31     weekday
# 13    September  2015     Sunday          0.99     weekend
# 14    September  2015     Sunday          1.33     weekend
# ...

# %%
#making barplot for avgprice during weekend and weekday
sns.barplot(x='type_of_day',y='AveragePrice',data=avocado_dates)
plt.show()

# %%
#avgprice during days of week
sns.barplot(x='day',y='AveragePrice',data=avocado_dates)
plt.show()

# %%
#avgprice during month
sns.barplot(x='month',y='AveragePrice',data=avocado_dates)
plt.tight_layout()

# %%
#AveragePrice of SmallBags
avocado.plot.scatter(x='AveragePrice',y='Small Bags')

# %%
#Avgprice of Large bags
avocado.plot.scatter(x='AveragePrice',y='Large Bags')

# %%
#AveragePrice of XLarge Bags
avocado.plot.scatter(x='AveragePrice',y='XLarge Bags')

# %%
#visualization with distribution plot
import warnings
warnings.filterwarnings('ignore')
sns.distplot(avocado["Total Volume"])
#plotting for viewing skewness
#skewed data

# %%
#visualization with distribution plot
sns.distplot(avocado["Total Bags"])
#plotting for viewing skewnwss

# %%
#visualization with distribution plot
sns.distplot(avocado["4046"])
#plotting for viewing skewnwss
#skewed data

# %%
#visualization with distribution plot
sns.distplot(avocado["4225"])
#plotting for viewing skewness
#skewed data

# %%
#visualization with distribution plot
sns.distplot(avocado["4770"])
#plotting for viewing skewnwss
#skewed data

# %%
#using LabelEncoder for converting into numerical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
avocado['type']=le.fit_transform(avocado.iloc[:,10])
avocado['region']=le.fit_transform(avocado['region'])

# %%
#view the head of the dataset
avocado.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-06-12          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8696.87     8603.62       93.25          0.0     0  2015       0
# 1     9505.56     9408.07       97.49          0.0     0  2015       0
# 2     8145.35     8042.21      103.14          0.0     0  2015       0
# 3     5811.16     5677.40      133.76          0.0     0  2015       0
# 4     6183.95     5986.26      197.69          0.0     0  2015       0

# %%
#visualization with distribution plot
sns.distplot(avocado["region"])
#plotting for viewing skewnwss
#skewed data

# %%
#finding outliers by plotting boxplot
avocado.iloc[:,1:].plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False,figsize=(20,20))
plt.tight_layout()
#plotting for checking outliers

# %%
#drop the column Date
avocado=avocado.drop(columns=["Date"])

# %%
#find the correlation matrix of each column
avocado.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# type                   NaN           NaN       NaN       NaN       NaN
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# region           -0.229408      0.236579  0.269481  0.215733  0.138092
#
# ...

# %%
#find the correlation matrix with visualization
plt.figure(figsize=(15,10))
sns.heatmap(avocado.corr(),annot=True)

# %%
#checking for skewness
avocado.skew()  #skewed data present
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type            0.000000
# year            1.828332
# region          0.288146
# dtype: float64

# %%
#removing skewness with log
import numpy as np
for col in avocado.columns:
    if avocado.skew().loc[col]>0.55:
        avocado[col]=np.log1p(avocado[col])

# %%
#again checking for skewness
avocado.skew()
# Out:
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# type            0.000000
# year            1.828332
# region          0.288146
# dtype: float64

# %% [markdown]
# Lets make the averageprice as output.To find this we have to use regression algorithm.

# %%
#let separate input and output variables to be used for the problem
x=avocado.drop(columns=['AveragePrice'])
x=pd.DataFrame(avocado.iloc[:,2:])
y=pd.DataFrame(avocado['AveragePrice'])

# %%
#scaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
#finding random state value with which our linear model learns maximum
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn import linear_model
from sklearn.model_selection import train_test_split
def maxr2score(reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        reg=linear_model.LinearRegression()
        reg.fit(x_train,y_train)
        y_pred=reg.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
reg=linear_model.LinearRegression()
r_state=maxr2score(reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.3150461627105763
# r2score corresponing to 43 is: 0.3767727669510028
# r2score corresponing to 44 is: 0.30394720891811755
# r2score corresponing to 45 is: 0.2527421716743309
# r2score corresponing to 46 is: 0.3631622536523462
# r2score corresponing to 47 is: 0.3463217143924697
# r2score corresponing to 48 is: 0.30982997366112863
# r2score corresponing to 49 is: 0.30329137736940426
# r2score corresponing to 50 is: 0.2944756936621161
# r2score corresponing to 51 is: 0.3429452338552963
# r2score corresponing to 52 is: 0.3147805721781187
# r2score corresponing to 53 is: 0.3456620582365616
# r2score corresponing to 54 is: 0.3545986580644199
# r2score corresponing to 55 is: 0.35334283332441774
# r2score corresponing to 56 is: 0.21547587318636863
# r2score corresponing to 57 is: 0.28741572260124426
# r2score corresponing to 58 is: 0.24032326024619444
# r2score corresponing to 59 is: 0.3598830689591993
# r2score corresponing to 60 is: 0.3525998839677492
# ...

# %%
#using GridSearchCV with KNR

from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={"n_neighbors":range(1,25)}
knr=KNeighborsRegressor()
gknr=GridSearchCV(knr,neighbors,cv=10)
gknr.fit(x,y)
gknr.best_params_
# Out:
# {'n_neighbors': 24}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(knr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        knr=KNeighborsRegressor(n_neighbors=24)
        knr.fit(x_train,y_train)
        y_predict=knr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
knr=KNeighborsRegressor(n_neighbors=24)
r_state=maxr2_score(knr,x,y)
# Out:
# r2score corresponing to 42 is: 0.5395783794646384
# r2score corresponing to 43 is: 0.6365899193308893
# r2score corresponing to 44 is: 0.6050318444975078
# r2score corresponing to 45 is: 0.5377785261171023
# r2score corresponing to 46 is: 0.5799409602795235
# r2score corresponing to 47 is: 0.5906832255921655
# r2score corresponing to 48 is: 0.5405736122255334
# r2score corresponing to 49 is: 0.564865025233313
# r2score corresponing to 50 is: 0.5631968168858716
# r2score corresponing to 51 is: 0.658709189469979
# r2score corresponing to 52 is: 0.6036722463810895
# r2score corresponing to 53 is: 0.6068941139627255
# r2score corresponing to 54 is: 0.6133087297647497
# r2score corresponing to 55 is: 0.5613984329586055
# r2score corresponing to 56 is: 0.5549954609149106
# r2score corresponing to 57 is: 0.5507994612466316
# r2score corresponing to 58 is: 0.5406650769940993
# r2score corresponing to 59 is: 0.607467942977068
# r2score corresponing to 60 is: 0.657269066686192
# ...

# %%
#Using GridSearchCV with DTR

from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
grid_param={"random_state":range(0,20)}
Gdt=GridSearchCV(dtr,param_grid=grid_param,scoring='r2',cv=10)
Gdt.fit(x,y)
Gdt.best_params_
# Out:
# {'random_state': 8}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(dtr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        dtr=DecisionTreeRegressor(random_state=8)
        dtr.fit(x_train,y_train)
        y_predict=dtr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
dtr=DecisionTreeRegressor(random_state=8)
r_state=maxr2_score(dtr,x,y)
# Out:
# r2score corresponing to 42 is: 0.6765712435297466
# r2score corresponing to 43 is: 0.783908592342516
# r2score corresponing to 44 is: 0.535652258223444
# r2score corresponing to 45 is: 0.7116420063852525
# r2score corresponing to 46 is: 0.6407026539038887
# r2score corresponing to 47 is: 0.6865072184158643
# r2score corresponing to 48 is: 0.6312169907915128
# r2score corresponing to 49 is: 0.7068531440533999
# r2score corresponing to 50 is: 0.681838566994082
# r2score corresponing to 51 is: 0.6149029824203825
# r2score corresponing to 52 is: 0.6098143624002867
# r2score corresponing to 53 is: 0.6570180860729309
# r2score corresponing to 54 is: 0.5853170367480101
# r2score corresponing to 55 is: 0.6522667877772181
# r2score corresponing to 56 is: 0.43469308111939353
# r2score corresponing to 57 is: 0.7034923510537441
# r2score corresponing to 58 is: 0.5584059491788893
# r2score corresponing to 59 is: 0.716508573780857
# r2score corresponing to 60 is: 0.6708632277079254
# ...

# %%
#Cross Validation for bias-variance tradeoff using cross-val-score
from sklearn.model_selection import cross_val_score
import numpy as np
regr_score_mean=cross_val_score(reg,x,y,cv=5,scoring="r2").mean()
regr_score_std=cross_val_score(reg,x,y,cv=5,scoring="r2").std()
print("mean r2 score of linearRegression :",regr_score_mean)
print("stadard deviation for r2 score of linearRegression :",regr_score_std)
print('\n')
knr_score_mean=cross_val_score(knr,x,y,cv=5,scoring="r2").mean()
knr_score_std=cross_val_score(knr,x,y,cv=5,scoring="r2").std()
print("mean r2 score of knr:",knr_score_mean)
print("standard deviation of r2score for knr:",knr_score_std)
print('\n')
dtr_score_mean=cross_val_score(dtr,x,y,cv=5,scoring="r2").mean()
dtr_score_std=cross_val_score(dtr,x,y,cv=5,scoring="r2").std()
print('\n')
print("mean r2 score of DecisionTreeRegression :",dtr_score_mean)
print("stadard deviation for r2 score of DecisionTreeeRegression :",dtr_score_std)
# Out:
# mean r2 score of linearRegression : 0.07309986395429235
# stadard deviation for r2 score of linearRegression : 0.12338013753706041
#
#
# mean r2 score of knr: 0.11789059870252097
# standard deviation of r2score for knr: 0.13573116064985644
#
#
#
#
# mean r2 score of DecisionTreeRegression : -0.2621805844230016
# stadard deviation for r2 score of DecisionTreeeRegression : 0.3674068726748552

# %%
#Using GridSearchCV With Ridge Operation

from sklearn.linear_model import Ridge
r_reg=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(r_reg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(r_reg,df_x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        r_reg=Ridge(alpha=1)
        r_reg.fit(x_train,y_train)
        y_predict=r_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
r_reg=Ridge(alpha=1)
r_state=maxr2_score(r_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.3172453255821195
# r2score corresponing to 43 is: 0.374210425747024
# r2score corresponing to 44 is: 0.3012781789714555
# r2score corresponing to 45 is: 0.2526034040136741
# r2score corresponing to 46 is: 0.3610943034047923
# r2score corresponing to 47 is: 0.34559482936029295
# r2score corresponing to 48 is: 0.31021549652090175
# r2score corresponing to 49 is: 0.30423148426960656
# r2score corresponing to 50 is: 0.2989318044338428
# r2score corresponing to 51 is: 0.3414269638232509
# r2score corresponing to 52 is: 0.3156987444952789
# r2score corresponing to 53 is: 0.3445050085734598
# r2score corresponing to 54 is: 0.35475817414973065
# r2score corresponing to 55 is: 0.3503698895471449
# r2score corresponing to 56 is: 0.22015716502692662
# r2score corresponing to 57 is: 0.29063581020183293
# r2score corresponing to 58 is: 0.24047755865620724
# r2score corresponing to 59 is: 0.3593164869906721
# r2score corresponing to 60 is: 0.3512091304198873
# ...

# %%
#Cross Validation for bias-variance tradeoff using cross-val-score
r_reg_score_mean=cross_val_score(r_reg,x,y,cv=5,scoring="r2").mean()
r_reg_score_std=cross_val_score(r_reg,x,y,cv=5,scoring="r2").std()
print("mean r2score for RidgeRegression:",r_reg_score_mean)
print("standard deviation in r2score for RidgeRegression:",r_reg_score_std)
# Out:
# mean r2score for RidgeRegression: 0.06923390530803726
# standard deviation in r2score for RidgeRegression: 0.12211053881301488

# %%
#Using GridSearchCV with Lasso Operation

import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameters={"alpha":[0.001,0.01,0.1,1]}
clf=GridSearchCV(lsreg,parameters,cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(lsreg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        lsreg=Lasso(alpha=0.01)
        lsreg.fit(x_train,y_train)
        y_predict=lsreg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
lsreg=Lasso(alpha=0.01)
r_state=maxr2_score(lsreg,x,y)
# Out:
# r2score corresponing to 42 is: 0.29697382926952787
# r2score corresponing to 43 is: 0.3178164770519094
# r2score corresponing to 44 is: 0.24709632178129304
# r2score corresponing to 45 is: 0.2512346414684262
# r2score corresponing to 46 is: 0.31787278062733015
# r2score corresponing to 47 is: 0.29475577262469765
# r2score corresponing to 48 is: 0.26610007064087504
# r2score corresponing to 49 is: 0.27641855428172357
# r2score corresponing to 50 is: 0.3114500881715485
# r2score corresponing to 51 is: 0.29315176224852246
# r2score corresponing to 52 is: 0.2867343725996012
# r2score corresponing to 53 is: 0.2921263357099453
# r2score corresponing to 54 is: 0.2968967191073427
# r2score corresponing to 55 is: 0.30676390934038766
# r2score corresponing to 56 is: 0.22898002442510257
# r2score corresponing to 57 is: 0.2635638876927494
# r2score corresponing to 58 is: 0.23425245383182758
# r2score corresponing to 59 is: 0.3095948204165637
# r2score corresponing to 60 is: 0.29267313225402847
# ...

# %%
#Cross Validation for bias-variance tradeoff using cross-val-score
Lsreg_score_mean=cross_val_score(lsreg,x,y,cv=5,scoring="r2").mean()
Lsreg_score_std=cross_val_score(lsreg,x,y,cv=5,scoring="r2").std()
print("mean r2score for Lasso:",Lsreg_score_mean)
print("standard deviation in r2score for lasso:",Lsreg_score_std)
# Out:
# mean r2score for Lasso: 0.17037074179876122
# standard deviation in r2score for lasso: 0.06326168797091726

# %%
#Using GradientBoosting Algorithm

from sklearn.ensemble import GradientBoostingRegressor
import warnings
warnings.filterwarnings("ignore")
gbr=GradientBoostingRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 1000}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(gbr,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        gbr=GradientBoostingRegressor(learning_rate=0.001, n_estimators=1000)
        gbr.fit(x_train,y_train)
        y_predict=gbr.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
gbr=GradientBoostingRegressor(learning_rate=0.001,n_estimators=1000)
r_state=maxr2_score(gbr,x,y)
# Out:
# r2score corresponing to 42 is: 0.4689817967267168
# r2score corresponing to 43 is: 0.4540270231666357
# r2score corresponing to 44 is: 0.4253859244318893
# r2score corresponing to 45 is: 0.4586247585494019
# r2score corresponing to 46 is: 0.48765822231717615
# r2score corresponing to 47 is: 0.5232267527414804
# r2score corresponing to 48 is: 0.45149400031023235
# r2score corresponing to 49 is: 0.4426180776230805
# r2score corresponing to 50 is: 0.46418864170504326
# r2score corresponing to 51 is: 0.46956924073839057
# r2score corresponing to 52 is: 0.4478402701698687
# r2score corresponing to 53 is: 0.46722324693126593
# r2score corresponing to 54 is: 0.45996068706744353
# r2score corresponing to 55 is: 0.45923324208606897
# r2score corresponing to 56 is: 0.4211188689419916
# r2score corresponing to 57 is: 0.46172259406714733
# r2score corresponing to 58 is: 0.4613192460011417
# r2score corresponing to 59 is: 0.4316435032260645
# r2score corresponing to 60 is: 0.48131280102952945
# ...

# %%
#Cross Validation for bias-variance tradeoff using cross-val-score
gbr_score_mean=cross_val_score(gbr,x,y,cv=5,scoring="r2").mean()
gbr_score_std=cross_val_score(gbr,x,y,cv=5,scoring="r2").std()
print("mean r2score for GradientBoostRegression:",gbr_score_mean)
print("standard deviation in r2score for GradientBoostRegression:",gbr_score_std)
# Out:
# mean r2score for GradientBoostRegression: 0.3018398788222666
# standard deviation in r2score for GradientBoostRegression: 0.07027446659424878

# %%
#Using ADABoost Regressor

from sklearn.ensemble import AdaBoostRegressor
ada_reg=AdaBoostRegressor()
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000],"base_estimator":[reg,lsreg,DecisionTreeRegressor()]}
clf=GridSearchCV(ada_reg,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'base_estimator': DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best'),
#  'learning_rate': 1,
#  'n_estimators': 500}

# %%
#creating a function maxr2_score which gives max r2 score with corresponding random state
def maxr2_score(ada_reg,x,y):
    maxr_score=0
    for r_state in range(42,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
        ada_reg=AdaBoostRegressor(learning_rate=1,n_estimators=500,base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best'))
        ada_reg.fit(x_train,y_train)
        y_predict=ada_reg.predict(x_test)
        r2_scr=r2_score(y_test,y_predict)
        print("r2score corresponing to",r_state,"is:",r2_scr)
        if r2_scr>maxr_score:
            maxr_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2_score corresponding to ",final_r_state,"is",maxr_score) 
    return final_r_state

# %%
#calling the function
ada_reg=AdaBoostRegressor(learning_rate=1,n_estimators=500,base_estimator=DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
            max_leaf_nodes=None, min_impurity_decrease=0.0,
            min_impurity_split=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best'))
r_state=maxr2_score(ada_reg,x,y)
# Out:
# r2score corresponing to 42 is: 0.8629758415812032
# r2score corresponing to 43 is: 0.8755174167570431
# r2score corresponing to 44 is: 0.8111870294134724
# r2score corresponing to 45 is: 0.8152703760221546
# r2score corresponing to 46 is: 0.8554704775904562
# r2score corresponing to 47 is: 0.7947576421373166
# r2score corresponing to 48 is: 0.825259892669954
# r2score corresponing to 49 is: 0.8682826906878596
# r2score corresponing to 50 is: 0.8322795662993872
# r2score corresponing to 51 is: 0.8635580843138964
# r2score corresponing to 52 is: 0.8598111844139207
# r2score corresponing to 53 is: 0.853767541751973
# r2score corresponing to 54 is: 0.8655761532717956
# r2score corresponing to 55 is: 0.8420637523998108
# r2score corresponing to 56 is: 0.7941367227241974
# r2score corresponing to 57 is: 0.8342489139463115
# r2score corresponing to 58 is: 0.8424167497715159
# r2score corresponing to 59 is: 0.8545448071630023
# r2score corresponing to 60 is: 0.8968095053219595
# ...

# %%
#Cross Validation for bias-variance tradeoff using cross-val-score
print("mean r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").mean())
print("standard deviationof  r2score for AdaBoostRegressor:",cross_val_score(ada_reg,x,y,cv=5,scoring="r2").std())
# Out:
# mean r2score for AdaBoostRegressor: 0.23133365416656057
# standard deviationof  r2score for AdaBoostRegressor: 0.17465418469994146

# %% [markdown]
# #since ADABoostRegressor gives the best r2score of 0.8968 corresponding to random_state 60.So with the change in random state and fitting the traing data using AdaBoostRegressor and using Predict function on the testing data.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=60,test_size=0.20)
ada_reg.fit(x_train,y_train)
y_pred=ada_reg.predict(x_test)

# %%
print("r2score is",r2_score(y_test,y_pred))
print("root mean squared error is",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2score is 0.8932823507918275
# root mean squared error is 0.0674414951136012

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(ada_reg,"ada_avocado.pkl")
# Out:
# ['ada_avocado.pkl']

# %% [markdown]
# # Now take the region as output.For this we have to use classification algorithm.

# %%
#let separate input and output variables to be used for this problem
x1=avocado.drop(columns=['region'])
x1=pd.DataFrame(avocado['region'])
y1=pd.DataFrame(avocado['region'])

# %%
#scaling down using standardscaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x1=sc.fit_transform(x1)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x1,y1,random_state=9,test_size=0.3,stratify=y1)

# %%
#importing algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
#creating object of the algorithm
lr=LogisticRegression()
knn=KNeighborsClassifier(n_neighbors=6)
sv=SVC()
dt=DecisionTreeClassifier(random_state=6)
rf=RandomForestClassifier()

# %%
#by using gridsearch cv finding best parameters
from sklearn.model_selection import GridSearchCV
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x1,y1)
gknn.best_params_
# Out:
# {'n_neighbors': 1}

# %%
#for SVC:
kernel={"kernel":["linear","rbf","poly"]}
gsv=GridSearchCV(sv,kernel,cv=10)
gsv.fit(x1,y1)
gsv.best_params_
# Out:
# {'kernel': 'poly'}

# %%
#for DCT:
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
gdt.fit(x1,y1)
gdt.best_params_
# Out:
# {'criterion': 'gini', 'random_state': 0}

# %%
#providing the parameters
knn=KNeighborsClassifier(n_neighbors=1)
sv=SVC(kernel="poly")
dt=DecisionTreeClassifier(random_state=0,criterion="gini")
lr=LogisticRegression()
rf=RandomForestClassifier()

# %%
models=[]
models.append(("LogisticRegression",lr))
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("RandomForestClassifier",rf))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('******************',name,'************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x1,y1,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot([0,1],[0,1],'r--')
    print('\n\n')
# Out:
# ****************** LogisticRegression ************************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
#
#
# accuracy_score 0.16228070175438597
#
#
# cross_val_score= 0.16811273899448942
#
#
# classification_report
#               precision    recall  f1-score   support
#
#           0       0.21      1.00      0.35        20
#           1       0.00      0.00      0.00        16
#           2       0.00      0.00      0.00        20
#           3       0.00      0.00      0.00        20
#           4       0.00      0.00      0.00        19
#           5       0.00      0.00      0.00        15
#           6       0.16      1.00      0.28        23
#           7       0.00      0.00      0.00         9
# ...

# %%
#showing the results of all the models
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score
# 0      LogisticRegression       16.228070        16.811274
# 1    KNeighborsClassifier      100.000000       100.000000
# 2                     SVC       64.692982        64.852368
# 3  DecisionTreeClassifier      100.000000       100.000000
# 4  RandomForestClassifier      100.000000       100.000000

# %% [markdown]
# #RandomForestClassifier,DecisionTreeClassifier and KNeighborsClassifier all give the best accuracy score of 100 and the cross val score is also good of all of these and it also takes cares of underfitting snd overfitting problem.So we can use any of them.

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(rf,'rf_avocado.pkl')
# Out:
# ['rf_avocado.pkl']

# %%
#load the model for further use
model=joblib.load('rf_avocado.pkl')
