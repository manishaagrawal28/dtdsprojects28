# %%
#importing pandas library
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#load the dataset and providing the columns names
census=pd.read_csv('census.csv',names=['age','workclass','fnlwgt','education','education-num','marital-status','occupation',
                                       'relationship','race','sex','capital-gain','capital-loss','hours-per-week',
                                      'native-country','income'],header=0)
census
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# 5       49            Private  160187            9th              5
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 7       31            Private   45781        Masters             14
# 8       42            Private  159449      Bachelors             13
# 9       37            Private  280464   Some-college             10
# 10      30          State-gov  141297      Bachelors             13
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# ...

# %%
#shape of the dataset
census.shape
# Out:
# (32560, 15)

# %%
#check the datatypes
census.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
#checking information
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
# age               32560 non-null int64
# workclass         32560 non-null object
# fnlwgt            32560 non-null int64
# education         32560 non-null object
# education-num     32560 non-null int64
# marital-status    32560 non-null object
# occupation        32560 non-null object
# relationship      32560 non-null object
# race              32560 non-null object
# sex               32560 non-null object
# capital-gain      32560 non-null int64
# capital-loss      32560 non-null int64
# hours-per-week    32560 non-null int64
# native-country    32560 non-null object
# income            32560 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#check all the columnsnames
census.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#converting categorical data into numerical form by using labelencoder

import numpy as np
for col in census.columns:
    if census[col].dtypes=='object':
        from sklearn.preprocessing import LabelEncoder
        le=LabelEncoder()
        census[col]=le.fit_transform(census[col].astype(str))

# %%
#show first five data
census.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 3   28          4  338409          9             13               2
# 4   37          4  284582         12             14               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    hours-per-week  native-country  income
# 0              13              39       0
# 1              40              39       0
# ...

# %%
#find statistical information of the data (mean,standard deviation etc)
census.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000   32560.000000
# mean      38.581634      3.868796  1.897818e+05     10.298249      10.080590
# std       13.640642      1.455879  1.055498e+05      3.870317       2.572709
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178315e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783630e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370545e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32560.000000  32560.000000  32560.000000  32560.000000  32560.000000
# mean         2.611794      6.572912      1.446376      3.665848      0.669195
# ...

# %%
#Counting gender 
census.groupby('sex').size()
# Out:
# sex
# 0    10771
# 1    21789
# dtype: int64

# %%
#checking whether there is a null value or not?
census.isnull().sum()
#no null data present in the dataset
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
#checking null values with visualization
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(census.isnull())  #no missing data present

# %%
#visualization with distribution plot for specic columns
import warnings
warnings.filterwarnings('ignore')
sns.distplot(census["age"]) #no skewed data present

# %%
#visualization with distribution plot for specic columns
sns.distplot(census["marital-status"])
#no skewed data present

# %%
#visualization with distribution plot for specic columns
sns.distplot(census["relationship"])
#skewed data present

# %%
#visualization with distribution plot for specic columns
sns.distplot(census["sex"])
#no skewed data present

# %%
#visualization by using histogram graph for education
plt.hist(census['education'],bins=10,color='g')
plt.title('Histogram for Education')
# Out:
# Text(0.5,1,'Histogram for Education')

# %%
plt.hist(census['occupation'],bins=10,color='r') 
plt.title('Histogram for occupation')
#plotting histogram graph for occupation column
# Out:
# Text(0.5,1,'Histogram for occupation')

# %%
#countplot of the income column
sns.countplot(census["income"])

# %%
#visualization with boxplot
census.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False,figsize=(15,15))
plt.tight_layout()  #plotting for checking outliers

# %%
#find the correlation matrix of the data
census.corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.003786 -0.076646  -0.010508       0.036527
# workclass       0.003786   1.000000 -0.016587   0.023537       0.052015
# fnlwgt         -0.076646  -0.016587  1.000000  -0.028156      -0.043159
# education      -0.010508   0.023537 -0.028156   1.000000       0.359172
# education-num   0.036527   0.052015 -0.043159   0.359172       1.000000
# marital-status -0.266292  -0.064798  0.028184  -0.038398      -0.069338
# occupation     -0.020946   0.255004  0.001554  -0.021274       0.109748
# relationship   -0.263698  -0.090449  0.008922  -0.010879      -0.094145
# race            0.028718   0.049720 -0.021278   0.014135       0.031825
# sex             0.088832   0.095942  0.026882  -0.027349       0.012256
# capital-gain    0.077674   0.033828  0.000437   0.030047       0.122627
# capital-loss    0.057775   0.012231 -0.010259   0.016744       0.079932
# ...

# %%
#find the correlation matrix with visualization
plt.figure(figsize=(15,15))
sns.heatmap(census.corr(),annot=True)  #most of the data is mildly correlated as we can see it in the heatmap

# %%
#removing outliers
from scipy.stats import zscore
z_score=abs(zscore(census))
print(census.shape)
census_data=census.loc[(z_score<3).all(axis=1)]
print(census_data.shape)
# Out:
# (32560, 15)
# (27417, 15)

# %%
#let separate input and output variables to be used for the problem
x=census_data.drop(columns=['income'])
x=pd.DataFrame(census_data.iloc[:,0:14])
y=pd.DataFrame(census_data['income'])

# %%
#checking for skewness
x.skew()
#skewed data present
# Out:
# age                0.483478
# workclass         -0.738023
# fnlwgt             0.626221
# education         -0.957458
# education-num     -0.143960
# marital-status    -0.044317
# occupation         0.131148
# relationship       0.750207
# race              -2.592931
# sex               -0.684115
# capital-gain       4.934878
# capital-loss      29.325736
# hours-per-week    -0.358396
# native-country    -5.460675
# dtype: float64

# %%
#removing skewness
import numpy as np
for col in x.columns:
    if x.skew().loc[col]>0.55:
        x[col]=np.log1p(x[col])

# %%
#again checking for skewness
x.skew()
# Out:
# age                0.483478
# workclass         -0.738023
# fnlwgt            -0.955594
# education         -0.957458
# education-num     -0.143960
# marital-status    -0.044317
# occupation         0.131148
# relationship       0.252965
# race              -2.592931
# sex               -0.684115
# capital-gain       3.112810
# capital-loss      24.846938
# hours-per-week    -0.358396
# native-country    -5.460675
# dtype: float64

# %%
#Using standardscaler tecnique for scaling the data

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %% [markdown]
# For this dataset we have to use classification algorithm

# %%
#splitting the data
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=9,test_size=0.3,stratify=y)

# %%
#importing algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# %%
#creating an object of algorithm
lr=LogisticRegression()
knn=KNeighborsClassifier(n_neighbors=6)
sv=SVC()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
gnb=GaussianNB()

# %%
#Using GRidSearchCV for finding best parameters
from sklearn.model_selection import GridSearchCV

# %%
#for knn:
neighbors={"n_neighbors":range(1,30)}
gknn=GridSearchCV(knn,neighbors,cv=10)
gknn.fit(x,y)
gknn.best_params_
# Out:
# {'n_neighbors': 28}

# %%
#for sv:
kernel={"kernel":["linear","rbf","poly"]}
gsv=GridSearchCV(sv,kernel,cv=10)
gsv.fit(x,y)
gsv.best_params_
# Out:
# {'kernel': 'rbf'}

# %%
#for DcT:
grid_param={"random_state":range(0,20),"criterion":['gini','entropy']}
gdt=GridSearchCV(dt,param_grid=grid_param,scoring='accuracy',cv=10)
gdt.fit(x,y)
gdt.best_params_
# Out:
# {'criterion': 'entropy', 'random_state': 13}

# %%
#for RandomForestClassifier
parameters={"n_estimators":[10,100,500,1000]}
clf=GridSearchCV(rf,parameters,cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'n_estimators': 100}

# %%
#providing parameters
lr=LogisticRegression()
knn=KNeighborsClassifier(n_neighbors=28)
sv=SVC(kernel="rbf")
dt=DecisionTreeClassifier(random_state=13,criterion="entropy")
rf=RandomForestClassifier(n_estimators=100)
gnb=GaussianNB()

# %%
models=[]
models.append(("LogisticRegression",lr))
models.append(("KNeighborsClassifier",knn))
models.append(("SVC",sv))
models.append(("DecisionTreeClassifier",dt))
models.append(("GaussianNB",gnb))
models.append(("RandomForestClassifier",rf))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
cvs=[]
roc_score=[]
for name,model in models:
    print('*********************',name,'***************************')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("accuracy_score",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("cross_val_score=",sc)
    cvs.append(sc*100)
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    roc_score.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print("\n")
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC=%0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive rate')
    plt.xlabel('False positive rate')
    print('\n\n')
# Out:
# ********************* LogisticRegression ***************************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
#
#
# accuracy_score 0.8301726233892536
#
#
# cross_val_score= 0.8279899878059096
# roc_auc_score= 0.6916688606695893
#
#
# classification_report
#               precision    recall  f1-score   support
#
#           0       0.85      0.94      0.90      6384
#           1       0.69      0.44      0.54      1842
#
# avg / total       0.82      0.83      0.82      8226
#
#
#
# [[6017  367]
#  [1030  812]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ********************* KNeighborsClassifier ***************************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
# ...

# %%
#show the results of all the models
result=pd.DataFrame({'Model':Model,'Accuracy_score':score,'Cross_Val_Score':cvs,'roc_auc_curve':roc_score})
result
# Out:
#                     Model  Accuracy_score  Cross_Val_Score  roc_auc_curve
# 0      LogisticRegression       83.017262        82.798999      69.166886
# 1    KNeighborsClassifier       84.014102        84.071905      73.227399
# 2                     SVC       84.451738        84.790430      71.346373
# 3  DecisionTreeClassifier       80.585947        80.924219      71.965056
# 4              GaussianNB       76.027231        75.920088      76.328086
# 5  RandomForestClassifier       85.655239        85.253682      75.810403

# %% [markdown]
# #RandomForestClassifier algorithm provides excellent accuracy,cross-val and auc-roc score.the model also takes into account of underfitting and overfitting problem.

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(rf,"rf_census.pkl")
# Out:
# ['rf_census.pkl']

# %%
#load the model
model=joblib.load('rf_census.pkl')
